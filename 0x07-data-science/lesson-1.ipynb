# %%
import pandas

# fetch data
data = pandas.read_csv('data/bank.csv')

# display results
print(data)
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
# read all male gender 
# fetch data
data = pandas.read_csv('data/bank.csv')

df = pandas.DataFrame(data)
males = df[df['Gender'] == 'Male']

print(males)
# Out:
#       Loan_ID Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002   Male      No      Graduate            No             5849
# 1    LP001003   Male     Yes      Graduate            No             4583
# 2    LP001005   Male     Yes      Graduate           Yes             3000
# 3    LP001006   Male     Yes  Not Graduate            No             2583
# 4    LP001008   Male      No      Graduate            No             6000
# ..        ...    ...     ...           ...           ...              ...
# 607  LP002964   Male     Yes  Not Graduate            No             3987
# 608  LP002974   Male     Yes      Graduate            No             3232
# 610  LP002979   Male     Yes      Graduate            No             4106
# 611  LP002983   Male     Yes      Graduate            No             8072
# 612  LP002984   Male     Yes      Graduate            No             7583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
# get gender 
data["Gender"]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
# get the marriage column
data["Married"]
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 609     No
# 610    Yes
# 611    Yes
# 612    Yes
# 613     No
# Name: Married, Length: 614, dtype: object

# %%
# get column education
data["Education"]
# Out:
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 609        Graduate
# 610        Graduate
# 611        Graduate
# 612        Graduate
# 613        Graduate
# Name: Education, Length: 614, dtype: object

# %%
# get self_employed column
data["Self_Employed"]
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4       No
#       ...
# 609     No
# 610     No
# 611     No
# 612     No
# 613    Yes
# Name: Self_Employed, Length: 614, dtype: object

# %%
# get ApplicantIncome column
data["ApplicantIncome"]
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
# get CoapplicantIncome
data["CoapplicantIncome"]
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
#         ...
# 609       0.0
# 610       0.0
# 611     240.0
# 612       0.0
# 613       0.0
# Name: CoapplicantIncome, Length: 614, dtype: float64

# %%
# get loanAmount cloumn
data["LoanAmount"]
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
# get property_area column
data["Property_Area"]
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
# get loan status column
data["Loan_Status"]
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
# check for empties
# we check if our records are empty
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# replace the empties with unkown
# Self_Employed has 32 records empty
# We want to clean the data by replacing empty with "Unknown"
# we use fillna to fill empties and we use inPlace = True to make sure empty is filled with Unkonw

data["Self_Employed"].fillna("unkown", inplace=True)

# %%
# check updates
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# print records 1 to 50 
data.head(50)
# Out:
#      Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0   LP001002    Male      No      Graduate            No             5849
# 1   LP001003    Male     Yes      Graduate            No             4583
# 2   LP001005    Male     Yes      Graduate           Yes             3000
# 3   LP001006    Male     Yes  Not Graduate            No             2583
# 4   LP001008    Male      No      Graduate            No             6000
# 5   LP001011    Male     Yes      Graduate           Yes             5417
# 6   LP001013    Male     Yes  Not Graduate            No             2333
# 7   LP001014    Male     Yes      Graduate            No             3036
# 8   LP001018    Male     Yes      Graduate            No             4006
# 9   LP001020    Male     Yes      Graduate            No            12841
# 10  LP001024    Male     Yes      Graduate            No             3200
# 11  LP001027    Male     Yes      Graduate        unkown             2500
# ...

# %%
# The mean is 146.412
# Empty loan amount records, 22 empty
#  Replace with the mean
mean = 146.412
data["LoanAmount"].fillna(146.412, inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64
